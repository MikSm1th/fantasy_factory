# %%
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
url = "https://dfsforecast.com/projections/nfl/fd"
r = requests.get(url)
r.text
# Out:
# '<!doctype html><html lang="en"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no"><meta name="theme-color" content="#000000"><link rel="manifest" href="/manifest.json"><link rel="shortcut icon" href="/favicon.ico"><script async src="https://www.googletagmanager.com/gtag/js?id=UA-146608705-1"></script><script src="https://js.stripe.com/v3/"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-T4C2HJ6LWF"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","G-T4C2HJ6LWF")</script><title>DFSForecast</title><link href="/static/css/2.6d928d8e.chunk.css" rel="stylesheet"><link href="/static/css/main.236cf6f8.chunk.css" rel="stylesheet"></head><body><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KP95B6M" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><div id="root"></div><scr
# ...

# %%
r.headers
# Out:
# {'Date': 'Sat, 16 Oct 2021 01:30:50 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'cache-control': 'max-age=0,no-cache,no-store,must-revalidate', 'vary': 'Accept-Encoding', 'age': '413', 'x-nf-request-id': '01FJ3BJ6Z1C9PMQEZZDZR8NWFF', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=YJAigsEbbroZy4xnXmLGwgconMpK%2BIzMVVvUYdDNFqVIK9QMWt4tWUxC0e06wT3GiIInfmF9g9Fo61oBz7%2BJ%2FFo3dBvjDpGkT9USxwWv1xPwk9KDkRJq%2Bmpdjhvwi%2FovXlA%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '69ed8631990b2bb3-ORD', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400, h3-29=":443"; ma=86400, h3-28=":443"; ma=86400, h3-27=":443"; ma=86400'}

# %%
page = soup(html)
page
# Out:
# <!DOCTYPE html>
# ...

# %%
rows = page.findAll('tr')

# %%
rows
# Out:
# []
