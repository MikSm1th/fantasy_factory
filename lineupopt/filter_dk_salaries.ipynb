# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/nfl/DKSalaries20211007.csv')
df2 = df1.query('Position!="QB" | Name=="Russell Wilson" | Name == "Matthew Stafford"')
df2.Name.unique()
#df2.tail()
# Out:
# array(['Cooper Kupp', 'Russell Wilson', 'Matthew Stafford', 'DK Metcalf',
#        'Tyler Lockett', 'Darrell Henderson Jr.', 'Robert Woods',
#        'Chris Carson', 'Tyler Higbee', 'Van Jefferson Jr.',
#        'Freddie Swain', 'DeSean Jackson', 'Gerald Everett', 'Will Dissly',
#        'Matt Gay', 'Jason Myers', 'Alex Collins', 'Rams ', 'Seahawks ',
#        'Sony Michel', 'Travis Homer', 'DeeJay Dallas', 'Johnny Mundt',
#        'Dee Eskridge', 'Penny Hart', 'Jake Funk', 'Nick Bellore',
#        'Tyler Ott', 'Phillip Dorsett II', 'Ryan Izzo', 'Jace Sternberger',
#        'Javian Hawkins', 'Kendall Blanton', 'J.J. Koski', 'Landen Akers',
#        'Cade Johnson', 'Aaron Fuller', 'Josh Johnson', 'Cody Thompson',
#        'Tutu Atwell', 'Ben Skowronek', 'Buddy Howell', 'Brycen Hopkins',
#        'Tyler Mabry', 'Colby Parkinson', 'Jacob Harris', 'Rashaad Penny',
#        'Raymond Calais', 'John Ursua', 'Cam Akers'], dtype=object)

# %%
injury_list = ['Chris Carson', 'Gerald Everett', 'Dee Eskridge','Rashaad Penny', 'John Ursua', 'Raymond Calais', 'Cam Akers']
df3 = df2.query("Name not in @injury_list")
df3.to_csv('data/nfl/DKSalaries20211007clean.csv')
