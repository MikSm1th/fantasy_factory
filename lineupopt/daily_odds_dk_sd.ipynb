# %%
from pydfs_lineup_optimizer import Site, Sport, get_optimizer

optimizer = get_optimizer(Site.DRAFTKINGS_CAPTAIN_MODE, Sport.FOOTBALL)
optimizer.load_players_from_csv("data/nfl/DKSalaries20211007clean.csv")
for lineup in optimizer.optimize(20, max_exposure=.3):
    print(lineup)
optimizer.export('data/nfl/dk_result20211007.csv')
# Out:
#  1. CPT     Cooper Kupp                   CPT   LAR            LAR@SEA  40.725         18600.0$
#  2. FLEX    Matt Gay                      FLEX  LAR            LAR@SEA  10.25          3600.0$
#  3. FLEX    Matthew Stafford              FLEX  LAR            LAR@SEA  24.6           11400.0$
#  4. FLEX    Sony Michel                   FLEX  LAR            LAR@SEA  3.95           1800.0$
#  5. FLEX    Tyler Lockett                 FLEX  SEA            LAR@SEA  19.32          9600.0$
#  6. FLEX    Van Jefferson Jr.             FLEX  LAR            LAR@SEA  11.9           4800.0$
#
# Fantasy Points 110.75
# Salary 49800.00
#
#  1. CPT     Cooper Kupp                   CPT   LAR            LAR@SEA  40.725         18600.0$
#  2. FLEX    Alex Collins                  FLEX  SEA            LAR@SEA  6.37           3200.0$
#  3. FLEX    Darrell Henderson Jr.         FLEX  LAR            LAR@SEA  16.5           8400.0$
# ...
