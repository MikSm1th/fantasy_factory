# %%
import rpy2.robjects as robjects
r = robjects.r
r.source('ml_fan_pipe.R')

wkly_plyr_stats_r = robjects.globalenv['wkly_plyr_stats']

# %%
wkly_plyr_stats_r(2021)
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7f85a874d8c0> [RTYPES.NILSXP]
