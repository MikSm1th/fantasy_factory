# %%
import pandas as pd
import numpy as np

# %% [raw]
# base = "https://raw.githubusercontent.com/"
# url_agg = "zzhangusf/Predicting-Fantasy-Football-Points-Using-Machine-Learning/master/data/aggregated_2015.csv"
# df_agg = pd.read_csv(base+url_agg)
# #df_agg.columns

# %% [raw]
# url_box = "zzhangusf/Predicting-Fantasy-Football-Points-Using-Machine-Learning/master/data/players_box_scores_2015.csv"
# df_box = pd.read_csv(base+url_box)
# #df_box.shape

# %% [markdown]
# ## Normalizing Names

# %%
names_df = pd.read_csv('data/all_nfl_team_abbr.csv')
names_df.head(3)
# Out:
#             TeamName fanduel_2015 statistics_2015 fantasy_2015 fanduel_2016  \
# 0  Arizona Cardinals          ari             ARI          ARI          ari
# 1    Atlanta Falcons          atl             ATL          ATL          atl
# 2   Baltimore Ravens          bal             BAL          BAL          bal
#
#   statistics_2016 fantasy_2016
# 0             ARI          ARI
# 1             ATL          ATL
# 2             BAL          BAL

# %% [raw]
# ?pd.DataFrame.reset_index

# %%
names_df.replace({"Oakland Raiders": "Las Vegas Raiders", \
                  "San Diego Chargers": "Los Angeles Chargers", \
                 "St.Louis / Los Angeles Rams": "Los Angeles Rams"}, inplace=True)

names_df.sort_values('TeamName', inplace=True)
names_df.drop(names_df.columns[1:], axis=1, inplace=True)
names_df1 = names_df.reset_index(drop=True)
#names_df1

# %%
def get_unique_team_names(df, col):
    temp_df = pd.read_csv(df) 
    temp_list = list(temp_df[col].unique())
    temp_list.sort()
    return temp_list

# %%
import glob

temp_lists=[]
temp_cols=[]
for file in glob.glob('data/202*_Fanduel_Results.csv'):
    temp_list = get_unique_team_names(file, 'Team')
    temp_col = file
    temp_cols.append(temp_col)
    temp_lists.append(temp_list)

# %%
print(temp_lists, temp_cols)
# Out:
# [['ari', 'atl', 'bal', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb', 'hou', 'ind', 'jac', 'kan', 'lac', 'lar', 'lvr', 'mia', 'min', 'nor', 'nwe', 'nyg', 'nyj', 'phi', 'pit', 'sea', 'sfo', 'tam', 'ten', 'was'], ['ari', 'atl', 'bal', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb', 'hou', 'ind', 'jac', 'kan', 'lac', 'lar', 'lvr', 'mia', 'min', 'nor', 'nwe', 'nyg', 'nyj', 'phi', 'pit', 'sea', 'sfo', 'tam', 'ten', 'was']] ['data/2020_Fanduel_Results.csv', 'data/2021_Fanduel_Results.csv']

# %%
names_df2 = pd.DataFrame(temp_lists).T
temp_cols_short = [i[5:17] for i in temp_cols]
names_df2.columns = temp_cols_short
#names_df2

# %%
wk_temp = pd.read_csv('data/wkly_plyr_stats_2020.csv')
#wk_temp.columns

# %%
team_list = list(wk_temp.recent_team.unique())
team_list.sort()
print(team_list)
# Out:
# ['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL', 'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LA', 'LAC', 'LV', 'MIA', 'MIN', 'NE', 'NO', 'NYG', 'NYJ', 'PHI', 'PIT', 'SEA', 'SF', 'TB', 'TEN', 'WAS']

# %%
names_df = pd.concat([names_df1, names_df2], axis=1)
names_df['2020_stats'] = team_list
names_df.head(3)
# Out:
#             TeamName 2020_Fanduel 2021_Fanduel 2020_stats
# 0  Arizona Cardinals          ari          ari        ARI
# 1    Atlanta Falcons          atl          atl        ATL
# 2   Baltimore Ravens          bal          bal        BAL

# %% [raw]
# ?pd.concat

# %%
wk_temp = pd.read_csv('data/wkly_plyr_stats_2021.csv')
#wk_temp.columns

# %%
team_list = list(wk_temp.recent_team.unique())
team_list.sort()
print(team_list)
# Out:
# ['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL', 'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LA', 'LAC', 'LV', 'MIA', 'MIN', 'NE', 'NO', 'NYG', 'NYJ', 'PHI', 'PIT', 'SEA', 'SF', 'TB', 'TEN', 'WAS']

# %%
names_df['2021_stats'] = team_list
names_df.head(3)
# Out:
#             TeamName 2020_Fanduel 2021_Fanduel 2020_stats 2021_stats
# 0  Arizona Cardinals          ari          ari        ARI        ARI
# 1    Atlanta Falcons          atl          atl        ATL        ATL
# 2   Baltimore Ravens          bal          bal        BAL        BAL

# %%
names_df.to_csv('data/all_nfl_team_abbr_2021.csv')
